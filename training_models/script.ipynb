# %%
import pandas as pd
import re
import json
import unicodedata

SKIP_COLUMNS = {
    "Postnatal_Maternal_Complications",
    "Neonatal__Fetal_Complications",
    "Antenatal_Peripartum_Maternal_Complications",
    "Mode_of_delivery2",
    "Any other Antenatal, Postnatal, or Delivery Complications both fetal and maternal"
}

def clean_feature_string(s):
    s = s.strip().lower()
    s = unicodedata.normalize('NFKD', s)
    s = re.sub(r'[\s_\-]+$', '', s)
    s = re.sub(r'^[\s_\-]+', '', s)
    s = re.sub(r'[^a-z0-9\s\(\)\[\]\{\}\.\'\"\/\-]+', '', s)
    s = s.strip()
    return s

def detect_multivalue_columns_strict(df):
    multivalue_cols = {}
    for col in df.columns:
        if col in SKIP_COLUMNS:
            continue
        has_multi = False
        unique_values = set()
        for val in df[col].dropna().astype(str):
            if re.search(r',| and ', val):
                has_multi = True
            for s in re.split(r'\s*,\s*|\s+and\s+', val):
                clean_val = clean_feature_string(s)
                if clean_val and clean_val.lower() != 'nan':
                    unique_values.add(clean_val)
        if has_multi and len(unique_values) > 1:
            multivalue_cols[col] = sorted(unique_values)
    return multivalue_cols

def expand_columns_simple(df, multivalue_cols):
    conversion_report = {}
    for col, values in multivalue_cols.items():
        conversion_report[col] = []
        for v in values:
            new_col = f"{col}__{v}"
            conversion_report[col].append(new_col)
            df[new_col] = df[col].astype(str).apply(
                lambda x: int(any(v == clean_feature_string(s) for s in re.split(r'\s*,\s*|\s+and\s+', x))) if pd.notna(x) else 0
            )
    return df.drop(columns=list(multivalue_cols.keys())), conversion_report

def update_json(json_path, multivalue_cols):
    try:
        with open(json_path, 'r') as f:
            data = json.load(f)
    except (FileNotFoundError, json.JSONDecodeError):
        data = {}
    expanded_map = {}
    for col, values in multivalue_cols.items():
        expanded_map[col] = [f"{col}__{v}" for v in values]
    data['multi_value_column_expansion'] = expanded_map
    with open(json_path, 'w') as f:
        json.dump(data, f, indent=4)

def multi_value_column_expander_simple(
    input_csv: str = None,
    output_csv: str = None,
    json_path: str = None,
    df: pd.DataFrame = None
) -> pd.DataFrame:
    if df is None:
        if input_csv is None:
            raise ValueError("Must provide either input_csv or df")
        df = pd.read_csv(input_csv)
    else:
        df = df.copy()
    multivalue_cols = detect_multivalue_columns_strict(df)
    if not multivalue_cols:
        print("No multi-value columns detected.")
        return df
    print("Multi-value columns detected and will be expanded (with cleaned, lower-case values):")
    for col, values in multivalue_cols.items():
        print(f"  {col}: {values}")
    df_new, conversion_report = expand_columns_simple(df, multivalue_cols)
    print("\nCONVERSION SUMMARY:")
    for orig_col, new_cols in conversion_report.items():
        print(f"  '{orig_col}' was expanded into: {new_cols}")
    if output_csv:
        df_new.to_csv(output_csv, index=False)
        print(f"Expanded CSV saved to: {output_csv}")
    if json_path:
        update_json(json_path, multivalue_cols)
        print(f"JSON metadata updated at: {json_path}")
    return df_new

# Example usage in a notebook cell:
# expanded_df = multi_value_column_expander_simple(
#     input_csv='yourfile.csv',
#     output_csv='output.csv',
#     json_path='Mode_of_delivery2.json'
# )
expanded_df = multi_value_column_expander_simple(input_csv='Final Data For Model Training September 17.csv', output_csv='cleaned_data.csv', json_path='Mode_of_delivery2.json')
# expanded_df = multi_value_column_expander_simple(df=my_df)
# Out:
# Multi-value columns detected and will be expanded (with cleaned, lower-case values):
#   First degree relative with following medical conditions: ['anemia', 'anomalous babies', 'asthma', 'bleeding disorder', 'cardiac arrest', 'cardiac defects', 'cardiac disease', 'congenital anomalies', 'deep vein thrombosis', 'diabetes mellitus (dm)', 'down syndrome', 'eclampsia', 'eclampsia /pre-eclampsia', 'epilepsy', 'hypertension', 'multiple pregnancy', 'neural tube defects', 'no significant problem', 'postpartum hemorrhage(pph)', 'pre-eclampsia', 'renal disease', 'thalasemia', 'thyroid disease', 'tuberculosis', 'twins']
#   PreviouslyDiagnosedMedicalConditions: ['anemia', 'asthma', 'cardiac disease', 'deep vein thrombosis after last delivery', 'diabetes mellitus (dm)', 'eclampsia', 'epilepsy', 'hypertension', 'hypertension (htn)', 'multiple pregnancy', 'no previously diagnosed problem', 'obstetric cholestasis', 'postpartum hemorrhage(pph)', 'pre-eclampsia', 'renal disease', 'thyroid disease', 'tuberculosis', "von willebrand's disease"]
#   Outcome of Previous Pregnancies (Select all that apply):: ['alive birth ( full term)', 'alive birth ( postdate)', 'alive birth ( preterm)', 'alive birth (full term)', 'alive birth (postdate)', 'alive birth (preterm)', 'alive birth (preterrm)', 'first trimester miscarriages', 'iud (after 28 weeks)', 'medical management of ectopic pregnancy', 'midtrimester miscarriages', 'no delivery previously', 'no previous pregnancy', 'previous molar pregnancy', 'recurrent miscarriages', 'ruptured ectopic pregnancy', 'stillbirth ( after 28 weeks)', 'stillbirth (after 28 weeks)']
#   Mode of Delivery in Previous Pregnancies: ['cesarean section ( planned)', 'cesarean section (emergency )', 'cesarean section (emergency)', 'cesarean section (planned)', 'no previous delivery', 'vaginal']
#   Any other Antenatal, Postnatal, or Delivery Complications both fetal, maternal: ['low birth weight', 'no', 'preterm delivery', 'yes']
#   If responded "Yes" in previous question, then please specify: ['acute renal failure', 'anemia', 'birth asphyxia', 'cardiac failure', 'cervical incompetence', 'congenital anomalies', 'congenital heart disease', 'congenital heart disease of neonate', 'deep vein thrombosis', 'diabetes mellitus (dm)', 'early neonatal death', 'eclampsia', 'fetal distress', 'fetal malpresentation', 'first trimester miscarriages', 'gestational diabetes mellitus (dm)', 'hypertension', 'icu admission', 'intrauterine growth restriction', 'intrauterine growth restriction(iugr)', 'iud', 'iugr', 'low birth weight', 'macrosomia', 'meconium aspiration syndrome', 'mentaly retarded child', 'mentaly retarded child in child', 'midtrimester miscarriage', 'midtrimester miscarriages', 'missed abortion', 'molar pregnancy', 'multiple birth defects', 'neonatal death', 'neonatal hypothyroidism', 'nicu admission', 'no previous complication', 'no previous delivery', 'obstetric cholestasis', 'obstructed labour', 'oligohydramnios', 'placenta previa', 'placental abruption', 'polyhydramnios', 'postnatal depression', 'postnatal sepsis', 'postpartum hemorrhage(pph)', 'pph', 'pre-eclampsia', 'preclampsia', 'preterm delivery', 'previous multiple pregnancy', 'pulmonary embolism', 'recurrent midtrimester miscarriages', 'recurrent miscarriages', 'rh incompatibility', 'rh incompatibility with raised antibody titre', 'ruptured uterus', 'shoulder dystocia', 'stillbirth', 'sudden intrauterine death', 'thalasemic child']
#   Other Symptoms (Select all that apply): ['abdominal discomfort', 'abdominal pain', 'altered mental status', 'backache', 'bleeding from gums', 'blood in sputum', 'blood in urine', 'blurring of vision', 'blurring of vision increased swelling of body (feet', 'breathlessnes', 'breathlessnesss', 'burning micturition', 'confusion', 'constipation', 'constipationbackachepelvic pain', 'constipationdiarrheablurring of vision', 'cough', 'diarrhea', 'dizziness', 'dizziness. reduced urine output', 'easy bruisability', 'edema', 'epigastric pain', 'eyes', 'face', 'fainting', 'fatigue', 'fever', 'fever with chills', 'fits', 'flue', 'foamy urine', 'frequent crying', 'frequent urination', 'gastroenteritis', 'generalized body aches', 'generalized fits', 'generalized severe abdominal pain', 'generalized weakness', 'headache', 'heartburn', 'heartburn diarrhea', 'heartburn shortness of breath', 'heavy menstrual bleeding', 'increased swelling of body', 'increased swelling of body (feet', 'increased thirst', 'increased urinary frequency', 'indigestion', 'insomnia', 'irritability', 'itching all over bodu', 'itching all over body', 'itching all over the body headache', 'legs', 'loss of appetite', 'loss of appetite gastroenteritis', 'lower abdominal pain', 'nasal bleeding', 'nasal congestion', 'nausea', 'nervousness', 'no active complaint', 'no other complaint', 'pain', 'pain epigastrium', 'pain in abdomen', 'pain in abdomen/backache', 'pain in renal area', 'pain in right shoulder', 'pain in stitchline', 'pain in stomach', 'pain in stomach/abdomen', 'pain lower abdomen', 'pain lower abdomen/stitchline', 'pain right shoulder', 'palpitations', 'passage of grape-like vesicles', 'pelvic pain', 'pelvic painpelvic pressure', 'pelvic painpelvic pressurevaginal discharge', 'pelvic pressure', 'perineal heaviness', 'recurrent uti', 'reduced urine output', 'severe pain abdomen', 'shortness of breath', 'shortness of breathn', 'sleep disturbance', 'sorethroat', 'spotting/brownish vaginal discharge', 'stress', 'sudden loss of uterine contractions', 'swelling', 'swelling of body', 'swelling of left leg', 'swelling/pain in a leg', 'swelling/pain in legs', 'syncope', 'urine output', 'uti', 'vagianl discharge', 'vaginal discharge', 'vertigo', 'vomiting', 'vomiting diarrhea', 'vomiting.', 'vulva', 'vulva)', 'vulva) itching all over body', 'weight loss', 'yellowish vaginal discharge']
#   Medicines in Use currently: ['antiallergic', 'antibiotics', 'antiepileptics', 'antihypertensive', 'antihypertensives', 'antithyroid', 'calamine lotion', 'calamine lotion.\ntab rigix', 'calcium', 'diuretics', 'folic acid', 'glucophage', 'inderol', 'inj claxane 40 mg daily', 'insulin', 'insuline', 'iron', 'iucd', 'labetalol', 'levothyroxine', 'levothyroxinee', 'loprin', 'no', 'no medicines', 'normal saline iv infusion', 'ocps', 'oral antibiotics', 'progesterone \nsupplemets', 'salbutamol inhaler', 'tab aldomet', 'tab envepe', 'tab fefan\ntab cac', 'tab folic acid', 'tab loprin\ntab aldomet', 'tab panadol', 'tab rigix', 'tab tegral od', 'tab urso', 'tab urso 500 mg', 'tabfefolvit', 'thyroxine', 'urso']
#   Previous Medicines Record (used for long term or frequently taken):: ['anti epileptics', 'antidepressants', 'antiepileptic', 'antiepileptics', 'antihypertensive', 'antihypertensives', 'antipypertensives', 'antithyroid', 'anxiolytics', 'att', 'calcium', 'cap fefolvit', 'cap fefolvit\ntab panadol', 'co ezi day', 'digoxin\nnifedipine', 'diuretics', 'glucophage', 'glucophage loprin antihypertensive', 'hematenics', 'inderol', 'insulin', 'iron', 'iucd', 'lnderol', 'loprin', 'montelukast\ninhaler', 'montelukast inhaler', 'motelukast\ninhaler', 'nikl', 'nil', 'nill', 'no', 'no medicines', 'no previous drug intake', 'no previous medicines', 'no record availble', 'ocps', 'oral antidiabetic', 'oral antidiabetics', 'oral antidiabteics', 'salbutamol inhaler', 'steroids', 'tab aldomet', 'tab aldomet .tab loprin', 'tab fefolvit', 'tab panadol\ntab neurobion', 'tegral', 'thyroxine', 'ventoline inhaler', 'warfarin']
#   Per abdominal examination: Presentation: ['any other', 'breech', 'cephalic', 'first trimester', 'not applicable']
#   Per speculum examination (If Yes, specify findings): ['bleeding', 'blood mixed liqour', 'blood mixed liquor', 'blood mixed liquor draining', 'blood stained liquor', 'blood stained liquor draining', 'brownish discharge', 'clear li', 'clear liqour', 'clear liqour draining', 'clear liquor', 'clear liquor draining', 'fishy odor discharge', 'foul smelly bleeding', 'grape like vesicles', 'intact membranes', 'meconium', 'meconium mixed liquor', 'mild bleed', 'mild bleeding', 'mild bleeding on pad', 'mild bleeding os open', 'normal fndings', 'os closed', 'os open', 'os open . mild bleeding', 'short cervical length', 'thick curdy white discharge', 'yellow white discharge', 'yellowish white discharge', 'yellowish white discharge with liquor']
#   Per vaginal examination (If Yes, specify findings): ['artifical rupture of membranes', 'bleeding', 'blood mixed liqour', 'blood mixed liquor draining', 'cervical tenderness', 'clear liqour', 'clear liqour draining', 'clear liquor', 'clear liquor draining', 'clearl iquor draining', 'cx dilated', 'cx drawn up', 'cx effaced', 'dilated', 'draining blood stained liquor', 'effaced', 'empty pelvis', 'foul-smelling yellowish discharge', 'heavy vaginal bleeding', 'intact membranes', 'large caput', 'liquor draining', 'meconium', 'meconium stained liquor', 'mild bleed', 'mild bleeding', 'mild bleeding os open', 'no bleeding', 'os closed', 'os open', 'os open fully effaced', 'os open mild bleed', 'presenting part high', 'soft fetal parts felt through os', 'thick paste meconium', 'yellow white discharge']
#   Postnatal_Symptoms: ['abdominal pain', 'absolute constipation', 'altered mental status', 'backache', 'blood in urine', 'blurred vision', 'blurring of vision', 'breathlessnes', 'breathlessnesss', 'burning micturation', 'burning micturition', 'confusion', 'constipation', 'cough', 'decreased urine output', 'discharge from wound', 'dizziness', 'eyes', 'eyes vulva', 'eyes vulva)', 'eyes)', 'face', 'fatigue', 'fatigue dizziness', 'feet', 'fever', 'foul smelly discharge', 'foul smelly vaginal discharge', 'frequent crying', 'generalized body aches', 'generalized body weakness', 'generalized generalized generalized generalized generalized weakness', 'generalized generalized generalized generalized weakness', 'generalized generalized generalized generalized weakness/body aches', 'generalized ill health', 'generalized ill health/body aches', 'generalized ill health/generalized body aches', 'generalized ill heath', 'generalized weakness', 'generalized weekness', 'headach', 'headache', 'heartburn', 'heavy bleeding', 'heavy vaginal bleeding', 'icu admission', 'increased swelling of body', 'increased swelling of body(feet', 'irregular bleeding', 'irritability', 'legs', 'loss of apetite', 'loss of appetite', 'low mood', 'nausea', 'no complaint', 'not delivered yet', 'pain', 'pain in abdomen', 'pain in legs', 'pain in renal area', 'pain in stitchline', 'pain in stomach', 'pain in stomach/abdomen', 'pain in stomach/pain in abdomen', 'pain in stomachp/ain in abdomen', 'pain in stomachp/pain in abdomen', 'pain lower abdomen', 'pain rt/lt leg', 'pallor', 'palpitations', 'pelvic pain', 'pelvic pressure', 'pussy discharge from wound', 'rritability', 'seizures', 'shortness of breath', 'sleep disturbance', 'stress', 'swelling', 'swelling in legs', 'swelling of (face', 'swelling of body', 'swelling of body(feet', 'swelling of right/left leg', 'swelling of right/right/left leg', 'swelling right leg', 'swelling rt/lt leg', 'swelling/pain in legs', 'unconscious', 'vaginal bleeding', 'vaginal discharge', 'vomiting', 'vulva)', 'yellowish vaginal discharge']
#   Postnatal_Examination: ['abdominal/uterine tenderness', 'b.p  more than 140/90 mmhg', 'b.p less than 80/60 mmhg', 'b.p more than 140/90', 'b.p more than 140/90 mmhg', 'bruised wound margins', 'cold peripheries', 'cracked nipples', 'edema', 'eyes', 'eyes)', 'feet', 'foul smelly lochia', 'foul smelly lochia present', 'foul smelly vaginal discharge', 'headache', 'hot', 'infected surgical/episiotomy wound', 'inflamed wound margins', 'inflammed wound margins', 'jaundice', 'legs', 'normal fndings', 'not delivered yet', 'pallor', 'pulse 100/min', 'pussy discharge', 'red', 'respiratory rate is22/min', 'seizures', 'swelling of (face', 'swelling of body', 'swelling of face', 'swollen left leg', 'temperature is  100.6f or  97f', 'tender right/left leg', 'value']
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[new_col] = df[col].astype(str).apply(
# C:\Users\zainm\AppData\Local\Temp\ipykernel_56136\3078980671.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   'Previous Medicines Record (used for long term or frequently taken):' was expanded into: ['Previous Medicines Record (used for long term or frequently taken):__anti epileptics', 'Previous Medicines Record (used for long term or frequently taken):__antidepressants', 'Previous Medicines Record (used for long term or frequently taken):__antiepileptic', 'Previous Medicines Record (used for long term or frequently taken):__antiepileptics', 'Previous Medicines Record (used for long term or frequently taken):__antihypertensive', 'Previous Medicines Record (used for long term or frequently taken):__antihypertensives', 'Previous Medicines Record (used for long term or frequently taken):__antipypertensives', 'Previous Medicines Record (used for long term or frequently taken):__antithyroid', 'Previous Medicines Record (used for long term or frequently taken):__anxiolytics', 'Previous Medicines Record (used for long term or frequently taken):__att', 'Previous Medicines Record (used for long term or frequently taken):__calcium', 'Previous Medicines Record (used for long term or frequently taken):__cap fefolvit', 'Previous Medicines Record (used for long term or frequently taken):__cap fefolvit\ntab panadol', 'Previous Medicines Record (used for long term or frequently taken):__co ezi day', 'Previous Medicines Record (used for long term or frequently taken):__digoxin\nnifedipine', 'Previous Medicines Record (used for long term or frequently taken):__diuretics', 'Previous Medicines Record (used for long term or frequently taken):__glucophage', 'Previous Medicines Record (used for long term or frequently taken):__glucophage loprin antihypertensive', 'Previous Medicines Record (used for long term or frequently taken):__hematenics', 'Previous Medicines Record (used for long term or frequently taken):__inderol', 'Previous Medicines Record (used for long term or frequently taken):__insulin', 'Previous Medicines Record (used for long term or frequently taken):__iron', 'Previous Medicines Record (used for long term or frequently taken):__iucd', 'Previous Medicines Record (used for long term or frequently taken):__lnderol', 'Previous Medicines Record (used for long term or frequently taken):__loprin', 'Previous Medicines Record (used for long term or frequently taken):__montelukast\ninhaler', 'Previous Medicines Record (used for long term or frequently taken):__montelukast inhaler', 'Previous Medicines Record (used for long term or frequently taken):__motelukast\ninhaler', 'Previous Medicines Record (used for long term or frequently taken):__nikl', 'Previous Medicines Record (used for long term or frequently taken):__nil', 'Previous Medicines Record (used for long term or frequently taken):__nill', 'Previous Medicines Record (used for long term or frequently taken):__no', 'Previous Medicines Record (used for long term or frequently taken):__no medicines', 'Previous Medicines Record (used for long term or frequently taken):__no previous drug intake', 'Previous Medicines Record (used for long term or frequently taken):__no previous medicines', 'Previous Medicines Record (used for long term or frequently taken):__no record availble', 'Previous Medicines Record (used for long term or frequently taken):__ocps', 'Previous Medicines Record (used for long term or frequently taken):__oral antidiabetic', 'Previous Medicines Record (used for long term or frequently taken):__oral antidiabetics', 'Previous Medicines Record (used for long term or frequently taken):__oral antidiabteics', 'Previous Medicines Record (used for long term or frequently taken):__salbutamol inhaler', 'Previous Medicines Record (used for long term or frequently taken):__steroids', 'Previous Medicines Record (used for long term or frequently taken):__tab aldomet', 'Previous Medicines Record (used for long term or frequently taken):__tab aldomet .tab loprin', 'Previous Medicines Record (used for long term or frequently taken):__tab fefolvit', 'Previous Medicines Record (used for long term ...
#   'Per abdominal examination: Presentation' was expanded into: ['Per abdominal examination: Presentation__any other', 'Per abdominal examination: Presentation__breech', 'Per abdominal examination: Presentation__cephalic', 'Per abdominal examination: Presentation__first trimester', 'Per abdominal examination: Presentation__not applicable']
#   'Per speculum examination (If Yes, specify findings)' was expanded into: ['Per speculum examination (If Yes, specify findings)__bleeding', 'Per speculum examination (If Yes, specify findings)__blood mixed liqour', 'Per speculum examination (If Yes, specify findings)__blood mixed liquor', 'Per speculum examination (If Yes, specify findings)__blood mixed liquor draining', 'Per speculum examination (If Yes, specify findings)__blood stained liquor', 'Per speculum examination (If Yes, specify findings)__blood stained liquor draining', 'Per speculum examination (If Yes, specify findings)__brownish discharge', 'Per speculum examination (If Yes, specify findings)__clear li', 'Per speculum examination (If Yes, specify findings)__clear liqour', 'Per speculum examination (If Yes, specify findings)__clear liqour draining', 'Per speculum examination (If Yes, specify findings)__clear liquor', 'Per speculum examination (If Yes, specify findings)__clear liquor draining', 'Per speculum examination (If Yes, specify findings)__fishy odor discharge', 'Per speculum examination (If Yes, specify findings)__foul smelly bleeding', 'Per speculum examination (If Yes, specify findings)__grape like vesicles', 'Per speculum examination (If Yes, specify findings)__intact membranes', 'Per speculum examination (If Yes, specify findings)__meconium', 'Per speculum examination (If Yes, specify findings)__meconium mixed liquor', 'Per speculum examination (If Yes, specify findings)__mild bleed', 'Per speculum examination (If Yes, specify findings)__mild bleeding', 'Per speculum examination (If Yes, specify findings)__mild bleeding on pad', 'Per speculum examination (If Yes, specify findings)__mild bleeding os open', 'Per speculum examination (If Yes, specify findings)__normal fndings', 'Per speculum examination (If Yes, specify findings)__os closed', 'Per speculum examination (If Yes, specify findings)__os open', 'Per speculum examination (If Yes, specify findings)__os open . mild bleeding', 'Per speculum examination (If Yes, specify findings)__short cervical length', 'Per speculum examination (If Yes, specify findings)__thick curdy white discharge', 'Per speculum examination (If Yes, specify findings)__yellow white discharge', 'Per speculum examination (If Yes, specify findings)__yellowish white discharge', 'Per speculum examination (If Yes, specify findings)__yellowish white discharge with liquor']
#   'Per vaginal examination (If Yes, specify findings)' was expanded into: ['Per vaginal examination (If Yes, specify findings)__artifical rupture of membranes', 'Per vaginal examination (If Yes, specify findings)__bleeding', 'Per vaginal examination (If Yes, specify findings)__blood mixed liqour', 'Per vaginal examination (If Yes, specify findings)__blood mixed liquor draining', 'Per vaginal examination (If Yes, specify findings)__cervical tenderness', 'Per vaginal examination (If Yes, specify findings)__clear liqour', 'Per vaginal examination (If Yes, specify findings)__clear liqour draining', 'Per vaginal examination (If Yes, specify findings)__clear liquor', 'Per vaginal examination (If Yes, specify findings)__clear liquor draining', 'Per vaginal examination (If Yes, specify findings)__clearl iquor draining', 'Per vaginal examination (If Yes, specify findings)__cx dilated', 'Per vaginal examination (If Yes, specify findings)__cx drawn up', 'Per vaginal examination (If Yes, specify findings)__cx effaced', 'Per vaginal examination (If Yes, specify findings)__dilated', 'Per vaginal examination (If Yes, specify findings)__draining blood stained liquor', 'Per vaginal examination (If Yes, specify findings)__effaced', 'Per vaginal examination (If Yes, specify findings)__empty pelvis', 'Per vaginal examination (If Yes, specify findings)__foul-smelling yellowish discharge', 'Per vaginal examination (If Yes, specify findings)__heavy vaginal bleeding', 'Per vaginal examination (If Yes, specify findings)__intact membranes', 'Per vaginal examination (If Yes, specify findings)__large caput', 'Per vaginal examination (If Yes, specify findings)__liquor draining', 'Per vaginal examination (If Yes, specify findings)__meconium', 'Per vaginal examination (If Yes, specify findings)__meconium stained liquor', 'Per vaginal examination (If Yes, specify findings)__mild bleed', 'Per vaginal examination (If Yes, specify findings)__mild bleeding', 'Per vaginal examination (If Yes, specify findings)__mild bleeding os open', 'Per vaginal examination (If Yes, specify findings)__no bleeding', 'Per vaginal examination (If Yes, specify findings)__os closed', 'Per vaginal examination (If Yes, specify findings)__os open', 'Per vaginal examination (If Yes, specify findings)__os open fully effaced', 'Per vaginal examination (If Yes, specify findings)__os open mild bleed', 'Per vaginal examination (If Yes, specify findings)__presenting part high', 'Per vaginal examination (If Yes, specify findings)__soft fetal parts felt through os', 'Per vaginal examination (If Yes, specify findings)__thick paste meconium', 'Per vaginal examination (If Yes, specify findings)__yellow white discharge']
#   'Postnatal_Symptoms' was expanded into: ['Postnatal_Symptoms__abdominal pain', 'Postnatal_Symptoms__absolute constipation', 'Postnatal_Symptoms__altered mental status', 'Postnatal_Symptoms__backache', 'Postnatal_Symptoms__blood in urine', 'Postnatal_Symptoms__blurred vision', 'Postnatal_Symptoms__blurring of vision', 'Postnatal_Symptoms__breathlessnes', 'Postnatal_Symptoms__breathlessnesss', 'Postnatal_Symptoms__burning micturation', 'Postnatal_Symptoms__burning micturition', 'Postnatal_Symptoms__confusion', 'Postnatal_Symptoms__constipation', 'Postnatal_Symptoms__cough', 'Postnatal_Symptoms__decreased urine output', 'Postnatal_Symptoms__discharge from wound', 'Postnatal_Symptoms__dizziness', 'Postnatal_Symptoms__eyes', 'Postnatal_Symptoms__eyes vulva', 'Postnatal_Symptoms__eyes vulva)', 'Postnatal_Symptoms__eyes)', 'Postnatal_Symptoms__face', 'Postnatal_Symptoms__fatigue', 'Postnatal_Symptoms__fatigue dizziness', 'Postnatal_Symptoms__feet', 'Postnatal_Symptoms__fever', 'Postnatal_Symptoms__foul smelly discharge', 'Postnatal_Symptoms__foul smelly vaginal discharge', 'Postnatal_Symptoms__frequent crying', 'Postnatal_Symptoms__generalized body aches', 'Postnatal_Symptoms__generalized body weakness', 'Postnatal_Symptoms__generalized generalized generalized generalized generalized weakness', 'Postnatal_Symptoms__generalized generalized generalized generalized weakness', 'Postnatal_Symptoms__generalized generalized generalized generalized weakness/body aches', 'Postnatal_Symptoms__generalized ill health', 'Postnatal_Symptoms__generalized ill health/body aches', 'Postnatal_Symptoms__generalized ill health/generalized body aches', 'Postnatal_Symptoms__generalized ill heath', 'Postnatal_Symptoms__generalized weakness', 'Postnatal_Symptoms__generalized weekness', 'Postnatal_Symptoms__headach', 'Postnatal_Symptoms__headache', 'Postnatal_Symptoms__heartburn', 'Postnatal_Symptoms__heavy bleeding', 'Postnatal_Symptoms__heavy vaginal bleeding', 'Postnatal_Symptoms__icu admission', 'Postnatal_Symptoms__increased swelling of body', 'Postnatal_Symptoms__increased swelling of body(feet', 'Postnatal_Symptoms__irregular bleeding', 'Postnatal_Symptoms__irritability', 'Postnatal_Symptoms__legs', 'Postnatal_Symptoms__loss of apetite', 'Postnatal_Symptoms__loss of appetite', 'Postnatal_Symptoms__low mood', 'Postnatal_Symptoms__nausea', 'Postnatal_Symptoms__no complaint', 'Postnatal_Symptoms__not delivered yet', 'Postnatal_Symptoms__pain', 'Postnatal_Symptoms__pain in abdomen', 'Postnatal_Symptoms__pain in legs', 'Postnatal_Symptoms__pain in renal area', 'Postnatal_Symptoms__pain in stitchline', 'Postnatal_Symptoms__pain in stomach', 'Postnatal_Symptoms__pain in stomach/abdomen', 'Postnatal_Symptoms__pain in stomach/pain in abdomen', 'Postnatal_Symptoms__pain in stomachp/ain in abdomen', 'Postnatal_Symptoms__pain in stomachp/pain in abdomen', 'Postnatal_Symptoms__pain lower abdomen', 'Postnatal_Symptoms__pain rt/lt leg', 'Postnatal_Symptoms__pallor', 'Postnatal_Symptoms__palpitations', 'Postnatal_Symptoms__pelvic pain', 'Postnatal_Symptoms__pelvic pressure', 'Postnatal_Symptoms__pussy discharge from wound', 'Postnatal_Symptoms__rritability', 'Postnatal_Symptoms__seizures', 'Postnatal_Symptoms__shortness of breath', 'Postnatal_Symptoms__sleep disturbance', 'Postnatal_Symptoms__stress', 'Postnatal_Symptoms__swelling', 'Postnatal_Symptoms__swelling in legs', 'Postnatal_Symptoms__swelling of (face', 'Postnatal_Symptoms__swelling of body', 'Postnatal_Symptoms__swelling of body(feet', 'Postnatal_Symptoms__swelling of right/left leg', 'Postnatal_Symptoms__swelling of right/right/left leg', 'Postnatal_Symptoms__swelling right leg', 'Postnatal_Symptoms__swelling rt/lt leg', 'Postnatal_Symptoms__swelling/pain in legs', 'Postnatal_Symptoms__unconscious', 'Postnatal_Symptoms__vaginal bleeding', 'Postnatal_Symptoms__vaginal discharge', 'Postnatal_Symptoms__vomiting', 'Postnatal_Symptoms__vulva)', 'Postnatal_Symptoms__yellowish vaginal discharge']
#   'Postnatal_Examination' was expanded into: ['Postnatal_Examination__abdominal/uterine tenderness', 'Postnatal_Examination__b.p  more than 140/90 mmhg', 'Postnatal_Examination__b.p less than 80/60 mmhg', 'Postnatal_Examination__b.p more than 140/90', 'Postnatal_Examination__b.p more than 140/90 mmhg', 'Postnatal_Examination__bruised wound margins', 'Postnatal_Examination__cold peripheries', 'Postnatal_Examination__cracked nipples', 'Postnatal_Examination__edema', 'Postnatal_Examination__eyes', 'Postnatal_Examination__eyes)', 'Postnatal_Examination__feet', 'Postnatal_Examination__foul smelly lochia', 'Postnatal_Examination__foul smelly lochia present', 'Postnatal_Examination__foul smelly vaginal discharge', 'Postnatal_Examination__headache', 'Postnatal_Examination__hot', 'Postnatal_Examination__infected surgical/episiotomy wound', 'Postnatal_Examination__inflamed wound margins', 'Postnatal_Examination__inflammed wound margins', 'Postnatal_Examination__jaundice', 'Postnatal_Examination__legs', 'Postnatal_Examination__normal fndings', 'Postnatal_Examination__not delivered yet', 'Postnatal_Examination__pallor', 'Postnatal_Examination__pulse 100/min', 'Postnatal_Examination__pussy discharge', 'Postnatal_Examination__red', 'Postnatal_Examination__respiratory rate is22/min', 'Postnatal_Examination__seizures', 'Postnatal_Examination__swelling of (face', 'Postnatal_Examination__swelling of body', 'Postnatal_Examination__swelling of face', 'Postnatal_Examination__swollen left leg', 'Postnatal_Examination__temperature is  100.6f or  97f', 'Postnatal_Examination__tender right/left leg', 'Postnatal_Examination__value']
# Expanded CSV saved to: cleaned_data.csv
# JSON metadata updated at: Mode_of_delivery2.json
